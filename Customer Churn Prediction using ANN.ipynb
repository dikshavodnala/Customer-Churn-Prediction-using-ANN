# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
# %matplotlib inline

# %%
df = pd.read_csv('WA_Fn-UseC_-Telco-Customer-Churn.csv')
df.head(5)
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0          No          No              No  Month-to-month              Yes
# 1          No          No              No        One year               No
# 2          No          No              No  Month-to-month              Yes
# 3         Yes          No              No        One year               No
# 4          No          No              No  Month-to-month              Yes
#
#                PaymentMethod MonthlyCharges  TotalCharges Churn
# 0           Electronic check          29.85         29.85    No
# 1               Mailed check          56.95        1889.5    No
# 2               Mailed check          53.85        108.15   Yes
# 3  Bank transfer (automatic)          42.30       1840.75    No
# 4           Electronic check          70.70        151.65   Yes
#
# [5 rows x 21 columns]

# %%
df.drop('customerID', axis='columns', inplace=True)
df.dtypes
# Out:
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %%
df.TotalCharges.values
# Out:
# array(['29.85', '1889.5', '108.15', ..., '346.45', '306.6', '6844.5'],
#       dtype=object)

# %%
df.MonthlyCharges.values
# Out:
# array([ 29.85,  56.95,  53.85, ...,  29.6 ,  74.4 , 105.65])

# %%
pd.to_numeric(df.TotalCharges, errors='coerce').isnull()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 7038    False
# 7039    False
# 7040    False
# 7041    False
# 7042    False
# Name: TotalCharges, Length: 7043, dtype: bool

# %%
df[pd.to_numeric(df.TotalCharges, errors='coerce').isnull()]
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 488   Female              0     Yes        Yes       0           No
# 753     Male              0      No        Yes       0          Yes
# 936   Female              0     Yes        Yes       0          Yes
# 1082    Male              0     Yes        Yes       0          Yes
# 1340  Female              0     Yes        Yes       0           No
# 3331    Male              0     Yes        Yes       0          Yes
# 3826    Male              0     Yes        Yes       0          Yes
# 4380  Female              0     Yes        Yes       0          Yes
# 5218    Male              0     Yes        Yes       0          Yes
# 6670  Female              0     Yes        Yes       0          Yes
# 6754    Male              0      No        Yes       0          Yes
#
#          MultipleLines InternetService       OnlineSecurity  \
# 488   No phone service             DSL                  Yes
# 753                 No              No  No internet service
# 936                 No             DSL                  Yes
# 1082               Yes              No  No internet service
# 1340  No phone service             DSL                  Yes
# 3331                No              No  No internet service
# 3826               Yes              No  No internet service
# 4380                No              No  No internet service
# 5218                No              No  No internet service
# 6670               Yes             DSL                   No
# 6754               Yes             DSL                  Yes
#
#              OnlineBackup     DeviceProtection          TechSupport  \
# 488                    No                  Yes                  Yes
# 753   No internet service  No internet service  No internet service
# 936                   Yes                  Yes                   No
# 1082  No internet service  No internet service  No internet service
# 1340                  Yes                  Yes                  Yes
# 3331  No internet service  No internet service  No internet service
# 3826  No internet service  No internet service  No internet service
# 4380  No internet service  No internet service  No internet service
# 5218  No internet service  No internet service  No internet service
# 6670                  Yes                  Yes                  Yes
# 6754                  Yes                   No                  Yes
#
#               StreamingTV      StreamingMovies  Contract PaperlessBilling  \
# 488                   Yes                   No  Two year              Yes
# 753   No internet service  No internet service  Two year               No
# 936                   Yes                  Yes  Two year               No
# 1082  No internet service  No internet service  Two year               No
# 1340                  Yes                   No  Two year               No
# 3331  No internet service  No internet service  Two year               No
# 3826  No internet service  No internet service  Two year               No
# 4380  No internet service  No internet service  Two year               No
# 5218  No internet service  No internet service  One year              Yes
# 6670                  Yes                   No  Two year               No
# 6754                   No                   No  Two year              Yes
#
#                   PaymentMethod  MonthlyCharges TotalCharges Churn
# 488   Bank transfer (automatic)           52.55                 No
# 753                Mailed check           20.25                 No
# 936                Mailed check           80.85                 No
# 1082               Mailed check           25.75                 No
# 1340    Credit card (automatic)           56.05                 No
# 3331               Mailed check           19.85                 No
# 3826               Mailed check           25.35                 No
# 4380               Mailed check           20.00                 No
# 5218               Mailed check           19.70                 No
# 6670               Mailed check           73.35                 No
# 6754  Bank transfer (automatic)           61.90                 No

# %%
df[pd.to_numeric(df.TotalCharges, errors='coerce').isnull()].shape
# Out:
# (11, 20)

# %%
df.shape
# Out:
# (7043, 20)

# %%
df.iloc[488]['TotalCharges']
# Out:
# ' '

# %%
df1 = df[df.TotalCharges!=' ']
df1.shape
# Out:
# (7032, 20)

# %%
df1.dtypes
# Out:
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %%
df1.TotalCharges = pd.to_numeric(df1.TotalCharges)
# Out:
# C:\Users\Diksha Vodnala\AppData\Local\Temp\ipykernel_14060\973151263.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.TotalCharges = pd.to_numeric(df1.TotalCharges)

# %%
df1.TotalCharges.dtypes
# Out:
# dtype('float64')

# %% [markdown]
# ### Data Visualization

# %%
tenure_churn_no = df1[df1.Churn=='No'].tenure
tenure_churn_yes = df1[df1.Churn=='Yes'].tenure

plt.xlabel('tenure')
plt.ylabel('Number of Customers')
plt.title('Customer Churn Prediction Visualization')

plt.hist([tenure_churn_yes, tenure_churn_no], color=['green', 'red'], label=['Churn=Yes', 'Churn=No'])
plt.legend()

# %%
mc_churn_no = df1[df1.Churn=='No'].MonthlyCharges
mc_churn_yes = df1[df1.Churn=='Yes'].MonthlyCharges

plt.xlabel('Monthly Charges')
plt.ylabel('Number of Customers')
plt.title('Customer Churn Prediction Visualization')

plt.hist([mc_churn_yes, mc_churn_no], color=['green', 'red'], label=['Churn=Yes', 'Churn=No'])
plt.legend()

# %%
def print_unique_col_values(df):
    for col in df:
        if df[col].dtypes=='object':
            print(f'{col}:{df[col].unique()}')

# %%
df1.replace('No internet service','No', inplace=True)
df1.replace('No phone service','No', inplace=True)
# Out:
# C:\Users\Diksha Vodnala\AppData\Local\Temp\ipykernel_14060\3179917863.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.replace('No internet service','No', inplace=True)
# C:\Users\Diksha Vodnala\AppData\Local\Temp\ipykernel_14060\3179917863.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.replace('No phone service','No', inplace=True)

# %%
print_unique_col_values(df1)
# Out:
# gender:['Female' 'Male']
# Partner:['Yes' 'No']
# Dependents:['No' 'Yes']
# PhoneService:['No' 'Yes']
# MultipleLines:['No' 'Yes']
# InternetService:['DSL' 'Fiber optic' 'No']
# OnlineSecurity:['No' 'Yes']
# OnlineBackup:['Yes' 'No']
# DeviceProtection:['No' 'Yes']
# TechSupport:['No' 'Yes']
# StreamingTV:['No' 'Yes']
# StreamingMovies:['No' 'Yes']
# Contract:['Month-to-month' 'One year' 'Two year']
# PaperlessBilling:['Yes' 'No']
# PaymentMethod:['Electronic check' 'Mailed check' 'Bank transfer (automatic)'
#  'Credit card (automatic)']
# Churn:['No' 'Yes']

# %%
yes_no_columns = ['Partner','Dependents','PhoneService','MultipleLines','OnlineSecurity',
                 'OnlineBackup','DeviceProtection','TechSupport','StreamingTV','StreamingMovies','PaperlessBilling','Churn']

for col in yes_no_columns:
    df1[col].replace({'Yes':1,'No':0}, inplace=True)
# Out:
# C:\Users\Diksha Vodnala\AppData\Local\Temp\ipykernel_14060\108100641.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1[col].replace({'Yes':1,'No':0}, inplace=True)

# %%
for col in df1:
    print(f'{col}:{df1[col].unique()}')
# Out:
# gender:['Female' 'Male']
# SeniorCitizen:[0 1]
# Partner:[1 0]
# Dependents:[0 1]
# tenure:[ 1 34  2 45  8 22 10 28 62 13 16 58 49 25 69 52 71 21 12 30 47 72 17 27
#   5 46 11 70 63 43 15 60 18 66  9  3 31 50 64 56  7 42 35 48 29 65 38 68
#  32 55 37 36 41  6  4 33 67 23 57 61 14 20 53 40 59 24 44 19 54 51 26 39]
# PhoneService:[0 1]
# MultipleLines:[0 1]
# InternetService:['DSL' 'Fiber optic' 'No']
# OnlineSecurity:[0 1]
# OnlineBackup:[1 0]
# DeviceProtection:[0 1]
# TechSupport:[0 1]
# StreamingTV:[0 1]
# StreamingMovies:[0 1]
# Contract:['Month-to-month' 'One year' 'Two year']
# PaperlessBilling:[1 0]
# PaymentMethod:['Electronic check' 'Mailed check' 'Bank transfer (automatic)'
#  'Credit card (automatic)']
# MonthlyCharges:[29.85 56.95 53.85 ... 63.1  44.2  78.7 ]
# TotalCharges:[  29.85 1889.5   108.15 ...  346.45  306.6  6844.5 ]
# Churn:[0 1]

# %%
df1['gender'].replace({'Female':1, 'Male':0}, inplace=True)
# Out:
# C:\Users\Diksha Vodnala\AppData\Local\Temp\ipykernel_14060\3951318906.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['gender'].replace({'Female':1, 'Male':0}, inplace=True)

# %%
df1['gender'].unique()
# Out:
# array([1, 0], dtype=int64)

# %%
df2 = pd.get_dummies(data=df1, columns=['InternetService','Contract','PaymentMethod'])
df2.columns
# Out:
# Index(['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'tenure',
#        'PhoneService', 'MultipleLines', 'OnlineSecurity', 'OnlineBackup',
#        'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies',
#        'PaperlessBilling', 'MonthlyCharges', 'TotalCharges', 'Churn',
#        'InternetService_DSL', 'InternetService_Fiber optic',
#        'InternetService_No', 'Contract_Month-to-month', 'Contract_One year',
#        'Contract_Two year', 'PaymentMethod_Bank transfer (automatic)',
#        'PaymentMethod_Credit card (automatic)',
#        'PaymentMethod_Electronic check', 'PaymentMethod_Mailed check'],
#       dtype='object')

# %%
df2.sample(5)
# Out:
#       gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 3630       1              0        0           0       4             1
# 555        1              0        1           1      56             1
# 1287       1              0        1           1      30             1
# 5999       0              0        0           0      35             1
# 5330       0              1        1           0      10             1
#
#       MultipleLines  OnlineSecurity  OnlineBackup  DeviceProtection  ...  \
# 3630              0               0             0                 0  ...
# 555               1               1             0                 1  ...
# 1287              1               0             1                 1  ...
# 5999              1               1             0                 1  ...
# 5330              0               0             1                 1  ...
#
#       InternetService_DSL  InternetService_Fiber optic  InternetService_No  \
# 3630                    0                            0                   1
# 555                     1                            0                   0
# 1287                    0                            1                   0
# 5999                    0                            1                   0
# 5330                    0                            1                   0
#
#       Contract_Month-to-month  Contract_One year  Contract_Two year  \
# 3630                        1                  0                  0
# 555                         0                  1                  0
# 1287                        1                  0                  0
# 5999                        0                  0                  1
# 5330                        1                  0                  0
#
#       PaymentMethod_Bank transfer (automatic)  \
# 3630                                        1
# 555                                         1
# 1287                                        0
# 5999                                        0
# 5330                                        0
#
#       PaymentMethod_Credit card (automatic)  PaymentMethod_Electronic check  \
# 3630                                      0                               0
# 555                                       0                               0
# 1287                                      0                               1
# 5999                                      0                               1
# 5330                                      0                               0
#
#       PaymentMethod_Mailed check
# 3630                           0
# 555                            0
# 1287                           0
# 5999                           0
# 5330                           1
#
# [5 rows x 27 columns]

# %%
df2.dtypes
# Out:
# gender                                       int64
# SeniorCitizen                                int64
# Partner                                      int64
# Dependents                                   int64
# tenure                                       int64
# PhoneService                                 int64
# MultipleLines                                int64
# OnlineSecurity                               int64
# OnlineBackup                                 int64
# DeviceProtection                             int64
# TechSupport                                  int64
# StreamingTV                                  int64
# StreamingMovies                              int64
# PaperlessBilling                             int64
# MonthlyCharges                             float64
# TotalCharges                               float64
# Churn                                        int64
# InternetService_DSL                          uint8
# InternetService_Fiber optic                  uint8
# InternetService_No                           uint8
# Contract_Month-to-month                      uint8
# Contract_One year                            uint8
# Contract_Two year                            uint8
# PaymentMethod_Bank transfer (automatic)      uint8
# PaymentMethod_Credit card (automatic)        uint8
# PaymentMethod_Electronic check               uint8
# PaymentMethod_Mailed check                   uint8
# dtype: object

# %%
cols_to_scale = ['tenure','MonthlyCharges','TotalCharges']

from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

df2[cols_to_scale] = scaler.fit_transform(df2[cols_to_scale])

# %%
df2.sample(3)
# Out:
#       gender  SeniorCitizen  Partner  Dependents    tenure  PhoneService  \
# 6375       1              0        0           0  0.000000             1
# 3709       0              0        0           0  0.000000             1
# 5242       0              0        0           0  0.267606             1
#
#       MultipleLines  OnlineSecurity  OnlineBackup  DeviceProtection  ...  \
# 6375              0               0             1                 0  ...
# 3709              1               0             0                 0  ...
# 5242              1               0             0                 1  ...
#
#       InternetService_DSL  InternetService_Fiber optic  InternetService_No  \
# 6375                    0                            1                   0
# 3709                    1                            0                   0
# 5242                    0                            1                   0
#
#       Contract_Month-to-month  Contract_One year  Contract_Two year  \
# 6375                        1                  0                  0
# 3709                        1                  0                  0
# 5242                        1                  0                  0
#
#       PaymentMethod_Bank transfer (automatic)  \
# 6375                                        0
# 3709                                        0
# 5242                                        0
#
#       PaymentMethod_Credit card (automatic)  PaymentMethod_Electronic check  \
# 6375                                      1                               0
# 3709                                      0                               0
# 5242                                      0                               1
#
#       PaymentMethod_Mailed check
# 6375                           0
# 3709                           1
# 5242                           0
#
# [3 rows x 27 columns]

# %% [markdown]
# ### Train Test Split

# %%
X = df2.drop('Churn',axis='columns')
y = df2['Churn']

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2,random_state=5)

# %%
X_train.shape
# Out:
# (5625, 26)

# %%
X_test.shape
# Out:
# (1407, 26)

# %%
X_train[:10]
# Out:
#       gender  SeniorCitizen  Partner  Dependents    tenure  PhoneService  \
# 5664       1              1        0           0  0.126761             1
# 101        1              0        1           1  0.000000             1
# 2621       0              0        1           0  0.985915             1
# 392        1              1        0           0  0.014085             1
# 1327       0              0        1           0  0.816901             1
# 3607       1              0        0           0  0.169014             1
# 2773       0              0        1           0  0.323944             0
# 1936       1              0        1           0  0.704225             1
# 5387       0              0        0           0  0.042254             0
# 4331       0              0        0           0  0.985915             1
#
#       MultipleLines  OnlineSecurity  OnlineBackup  DeviceProtection  ...  \
# 5664              0               0             0                 1  ...
# 101               0               0             0                 0  ...
# 2621              0               0             1                 1  ...
# 392               0               0             0                 0  ...
# 1327              1               0             0                 1  ...
# 3607              0               1             0                 0  ...
# 2773              0               0             0                 1  ...
# 1936              0               1             1                 0  ...
# 5387              0               0             0                 0  ...
# 4331              1               0             0                 0  ...
#
#       InternetService_DSL  InternetService_Fiber optic  InternetService_No  \
# 5664                    0                            1                   0
# 101                     0                            0                   1
# 2621                    1                            0                   0
# 392                     1                            0                   0
# 1327                    0                            1                   0
# 3607                    1                            0                   0
# 2773                    1                            0                   0
# 1936                    1                            0                   0
# 5387                    1                            0                   0
# 4331                    0                            0                   1
#
#       Contract_Month-to-month  Contract_One year  Contract_Two year  \
# 5664                        1                  0                  0
# 101                         1                  0                  0
# 2621                        0                  0                  1
# 392                         1                  0                  0
# 1327                        0                  1                  0
# 3607                        0                  1                  0
# 2773                        1                  0                  0
# 1936                        0                  1                  0
# 5387                        1                  0                  0
# 4331                        0                  0                  1
#
#       PaymentMethod_Bank transfer (automatic)  \
# 5664                                        0
# 101                                         0
# 2621                                        0
# 392                                         0
# 1327                                        1
# 3607                                        0
# 2773                                        0
# 1936                                        1
# 5387                                        0
# 4331                                        1
#
#       PaymentMethod_Credit card (automatic)  PaymentMethod_Electronic check  \
# 5664                                      1                               0
# 101                                       0                               1
# 2621                                      1                               0
# 392                                       0                               1
# 1327                                      0                               0
# 3607                                      0                               0
# 2773                                      0                               1
# 1936                                      0                               0
# 5387                                      0                               1
# 4331                                      0                               0
#
#       PaymentMethod_Mailed check
# 5664                           0
# 101                            0
# 2621                           0
# 392                            0
# 1327                           0
# 3607                           1
# 2773                           0
# 1936                           0
# 5387                           0
# 4331                           0
#
# [10 rows x 26 columns]

# %%
len(X_train.columns)
# Out:
# 26

# %%
import tensorflow as tf
from tensorflow import keras


model = keras.Sequential([
    keras.layers.Dense(26, input_shape=(26,), activation='relu'),
    keras.layers.Dense(15, activation='relu'),
    keras.layers.Dense(1, activation='sigmoid')
])

model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

model.fit(X_train, y_train, epochs=100)
# Out:
# Epoch 1/100
# 176/176 [==============================] - 2s 2ms/step - loss: 0.4928 - accuracy: 0.7532
# Epoch 2/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4262 - accuracy: 0.7943
# Epoch 3/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4177 - accuracy: 0.8014
# Epoch 4/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4142 - accuracy: 0.8020
# Epoch 5/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4109 - accuracy: 0.8071
# Epoch 6/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4090 - accuracy: 0.8069
# Epoch 7/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4073 - accuracy: 0.8084
# Epoch 8/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4059 - accuracy: 0.8098
# Epoch 9/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4045 - accuracy: 0.8089
# Epoch 10/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4030 - accuracy: 0.8112
# Epoch 11/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4021 - accuracy: 0.8121
# Epoch 12/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3996 - accuracy: 0.8126
# Epoch 13/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3989 - accuracy: 0.8142
# Epoch 14/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3976 - accuracy: 0.8160
# Epoch 15/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3971 - accuracy: 0.8142
# Epoch 16/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3954 - accuracy: 0.8188
# Epoch 17/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3945 - accuracy: 0.8142
# Epoch 18/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3924 - accuracy: 0.8188
# Epoch 19/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3917 - accuracy: 0.8183
# Epoch 20/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3924 - accuracy: 0.8196
# Epoch 21/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3904 - accuracy: 0.8206
# Epoch 22/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3889 - accuracy: 0.8213
# Epoch 23/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3895 - accuracy: 0.8208
# Epoch 24/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3889 - accuracy: 0.8206
# Epoch 25/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3876 - accuracy: 0.8181
# Epoch 26/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3864 - accuracy: 0.8206
# Epoch 27/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3859 - accuracy: 0.8201
# Epoch 28/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3845 - accuracy: 0.8220
# Epoch 29/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3831 - accuracy: 0.8210
# Epoch 30/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3833 - accuracy: 0.8219
# Epoch 31/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3827 - accuracy: 0.8228
# Epoch 32/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3815 - accuracy: 0.8224
# Epoch 33/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3812 - accuracy: 0.8204
# Epoch 34/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3800 - accuracy: 0.8229
# Epoch 35/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3800 - accuracy: 0.8217
# Epoch 36/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3802 - accuracy: 0.8219
# Epoch 37/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3785 - accuracy: 0.8238
# Epoch 38/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3782 - accuracy: 0.8226
# Epoch 39/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3764 - accuracy: 0.8235
# Epoch 40/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3769 - accuracy: 0.8256
# Epoch 41/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3762 - accuracy: 0.8260
# Epoch 42/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3746 - accuracy: 0.8236
# Epoch 43/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3747 - accuracy: 0.8256
# Epoch 44/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3734 - accuracy: 0.8251
# Epoch 45/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3738 - accuracy: 0.8244
# Epoch 46/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3728 - accuracy: 0.8267
# Epoch 47/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3722 - accuracy: 0.8267
# Epoch 48/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3716 - accuracy: 0.8260
# Epoch 49/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3722 - accuracy: 0.8281
# Epoch 50/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3701 - accuracy: 0.8251
# Epoch 51/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3688 - accuracy: 0.8268
# Epoch 52/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3693 - accuracy: 0.8251
# Epoch 53/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3694 - accuracy: 0.8272
# Epoch 54/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3670 - accuracy: 0.8290
# Epoch 55/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3668 - accuracy: 0.8261
# Epoch 56/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3663 - accuracy: 0.8274
# Epoch 57/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3669 - accuracy: 0.8260
# Epoch 58/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3658 - accuracy: 0.8277
# Epoch 59/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3638 - accuracy: 0.8263
# Epoch 60/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3649 - accuracy: 0.8293
# Epoch 61/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3638 - accuracy: 0.8295
# Epoch 62/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3629 - accuracy: 0.8311
# Epoch 63/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3624 - accuracy: 0.8295
# Epoch 64/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3630 - accuracy: 0.8283
# Epoch 65/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3622 - accuracy: 0.8263
# Epoch 66/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3623 - accuracy: 0.8308
# Epoch 67/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3605 - accuracy: 0.8295
# Epoch 68/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3603 - accuracy: 0.8284
# Epoch 69/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3600 - accuracy: 0.8288
# Epoch 70/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3595 - accuracy: 0.8290
# Epoch 71/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3592 - accuracy: 0.8295
# Epoch 72/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3579 - accuracy: 0.8338
# Epoch 73/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3584 - accuracy: 0.8316
# Epoch 74/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3571 - accuracy: 0.8308
# Epoch 75/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3572 - accuracy: 0.8299
# Epoch 76/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3573 - accuracy: 0.8318
# Epoch 77/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3570 - accuracy: 0.8311
# Epoch 78/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3556 - accuracy: 0.8329
# Epoch 79/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3556 - accuracy: 0.8281
# Epoch 80/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3547 - accuracy: 0.8332
# Epoch 81/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3536 - accuracy: 0.8315
# Epoch 82/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3557 - accuracy: 0.8316
# Epoch 83/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3535 - accuracy: 0.8343
# Epoch 84/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3534 - accuracy: 0.8332
# Epoch 85/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3529 - accuracy: 0.8334
# Epoch 86/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3537 - accuracy: 0.8325
# Epoch 87/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3531 - accuracy: 0.8320
# Epoch 88/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3518 - accuracy: 0.8340
# Epoch 89/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3517 - accuracy: 0.8318
# Epoch 90/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3496 - accuracy: 0.8370
# Epoch 91/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3488 - accuracy: 0.8393
# Epoch 92/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3512 - accuracy: 0.8345
# Epoch 93/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3492 - accuracy: 0.8336
# Epoch 94/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3505 - accuracy: 0.8348
# Epoch 95/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3488 - accuracy: 0.8336
# Epoch 96/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3480 - accuracy: 0.8352
# Epoch 97/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3481 - accuracy: 0.8368
# Epoch 98/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3487 - accuracy: 0.8372
# Epoch 99/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3479 - accuracy: 0.8363
# Epoch 100/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3464 - accuracy: 0.8363

# %%
model.evaluate(X_test, y_test)
# Out:
# 44/44 [==============================] - 0s 2ms/step - loss: 0.4982 - accuracy: 0.7726
# [0.49815741181373596, 0.7725657224655151]

# %%
yp = model.predict(X_test)
yp[:5]
# Out:
# 44/44 [==============================] - 0s 1ms/step
# array([[0.20015264],
#        [0.65558696],
#        [0.00081788],
#        [0.7074986 ],
#        [0.54545426]], dtype=float32)

# %%
y_test[:5]
# Out:
# 2660    0
# 744     0
# 5579    1
# 64      1
# 3287    1
# Name: Churn, dtype: int64

# %%
y_pred=[]
for ele in yp:
    if ele > 0.5:
        y_pred.append(1)
    else:
        y_pred.append(0)

# %%
y_pred[:5]
# Out:
# [0, 1, 0, 1, 1]

# %%
from sklearn.metrics import confusion_matrix , classification_report

print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.89      0.85       999
#            1       0.64      0.50      0.56       408
#
#     accuracy                           0.77      1407
#    macro avg       0.73      0.69      0.70      1407
# weighted avg       0.76      0.77      0.76      1407

# %%
import seaborn as sn
cm = tf.math.confusion_matrix(predictions=y_pred,labels=y_test)

plt.figure(figsize = (10,7))
sn.heatmap(cm, annot=True, fmt='d')
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(69.0, 0.5, 'Truth')
